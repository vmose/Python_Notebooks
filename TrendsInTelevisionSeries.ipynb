# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv(r'C:\Input\TV Series.csv')
df.head()
# Out:
#       Series Title Release Year Runtime                    Genre Rating  \
# 0        Wednesday     (2022– )  45 min   Comedy, Crime, Fantasy    8.2
# 1      Yellowstone     (2018– )  60 min           Drama, Western    8.7
# 2  The White Lotus  (2021–2023)  60 min            Comedy, Drama    7.9
# 3             1923  (2022–2023)  60 min           Drama, Western    8.6
# 4        Jack Ryan     (2018– )  60 min  Action, Drama, Thriller    8.0
#
#                                                 Cast  \
# 0  Jenna Ortega, Hunter Doohan, Percy Hynes White...
# 1  Kevin Costner, Luke Grimes, Kelly Reilly, Wes ...
# 2  Jennifer Coolidge, Jon Gries, F. Murray Abraha...
# 3  Harrison Ford, Helen Mirren, Brandon Sklenar, ...
# 4  John Krasinski, Wendell Pierce, Michael Kelly,...
#
#                                             Synopsis
# 0  Follows Wednesday Addams' years as a student, ...
# 1  A ranching family in Montana faces off against...
# 2  Set in a tropical resort, it follows the explo...
# 3  The Duttons face a new set of challenges in th...
# 4  Up-and-coming CIA analyst, Jack Ryan, is thrus...

# %%
df.sort_values('Rating',ascending=False)
# Out:
#              Series Title Release Year Runtime                      Genre  \
# 2790   His Dark Materials       (2003)    ****  Adventure, Drama, Fantasy
# 8134   Roadworthy Rescues     (2022– )    ****                       ****
# 9173   Dallyeola Bangtan!     (2015– )    ****                  Game-Show
# 202                 Bluey     (2018– )   7 min          Animation, Family
# 16621        Breaking Bad  (2008–2013)  49 min     Crime, Drama, Thriller
# ...                   ...          ...     ...                        ...
# 33809      The Last of Us     (2023– )    ****   Action, Adventure, Drama
# 44659      The Last of Us     (2023– )    ****   Action, Adventure, Drama
# 4053    Gangs of New York          NaN    ****                      Drama
# 6437           Unsinkable          NaN    ****                Action, War
# 35859      The Last of Us     (2023– )    ****   Action, Adventure, Drama
#
#       Rating                                               Cast  \
# 2790     9.7  Terence Stamp, Kenneth Cranham, Bill Paterson,...
# 8134     9.6  Derek Bieri, Jessica Bieri, Dan Dosemagen, Car...
# 9173     9.6                                  RM, V, Jin, Jimin
# 202      9.6  David McCormack, Melanie Zanetti, Ninthe van S...
# 16621    9.5  Bryan Cranston, Aaron Paul, Anna Gunn, Betsy B...
# ...      ...                                                ...
# 33809   ****  Pedro Pascal, Bella Ramsey, Gabriel Luna, Merl...
# 44659   ****  Pedro Pascal, Bella Ramsey, Gabriel Luna, Merl...
# 4053    ****                                                NaN
# 6437    ****  Thomas Brodie-Sangster, John Malkovich, Nathal...
# 35859   ****  Pedro Pascal, Bella Ramsey, Gabriel Luna, Merl...
#
#                                                 Synopsis
# 2790   A young girl sets out on a quest that takes he...
# 8134   Follow Derek Bieri as he seeks out abandoned c...
# 9173   Run BTS (Dallyeola Bangtan!) is a South Korean...
# 202    The slice-of-life adventures of an Australian ...
# 16621  A chemistry teacher diagnosed with inoperable ...
# ...                                                  ...
# 33809  Joel and Ellie, a pair connected through the h...
# 44659  Joel and Ellie, a pair connected through the h...
# 4053                                   Plot under wraps.
# 6437   A raw young officer and a handful of desperate...
# 35859  Joel and Ellie, a pair connected through the h...
#
# [50000 rows x 7 columns]

# %%
x=df[df['Release Year'].str.startswith('(2010')==True]
x
# Out:
#            Series Title Release Year Runtime                    Genre Rating  \
# 11     The Walking Dead  (2010–2022)  44 min  Drama, Horror, Thriller    8.1
# 134         Blue Bloods     (2010– )  43 min    Crime, Drama, Mystery    7.7
# 155            Sherlock  (2010–2017)  88 min    Crime, Drama, Mystery    9.1
# 196       Downton Abbey  (2010–2015)  58 min           Drama, Romance    8.7
# 227       Hawaii Five-0  (2010–2020)  42 min     Action, Crime, Drama    7.4
# ...                 ...          ...     ...                      ...    ...
# 49761  The Walking Dead  (2010–2022)  44 min  Drama, Horror, Thriller    8.1
# 49811  The Walking Dead  (2010–2022)  44 min  Drama, Horror, Thriller    8.1
# 49861  The Walking Dead  (2010–2022)  44 min  Drama, Horror, Thriller    8.1
# 49911  The Walking Dead  (2010–2022)  44 min  Drama, Horror, Thriller    8.1
# 49961  The Walking Dead  (2010–2022)  44 min  Drama, Horror, Thriller    8.1
#
#                                                     Cast  \
# 11     Andrew Lincoln, Norman Reedus, Melissa McBride...
# 134    Donnie Wahlberg, Bridget Moynahan, Will Estes,...
# 155    Benedict Cumberbatch, Martin Freeman, Una Stub...
# 196    Hugh Bonneville, Phyllis Logan, Elizabeth McGo...
# 227    Alex O'Loughlin, Scott Caan, Taylor Wily, Dani...
# ...                                                  ...
# 49761  Andrew Lincoln, Norman Reedus, Melissa McBride...
# 49811  Andrew Lincoln, Norman Reedus, Melissa McBride...
# 49861  Andrew Lincoln, Norman Reedus, Melissa McBride...
# 49911  Andrew Lincoln, Norman Reedus, Melissa McBride...
# 49961  Andrew Lincoln, Norman Reedus, Melissa McBride...
#
#                                                 Synopsis
# 11     Sheriff Deputy Rick Grimes wakes up from a com...
# 134           Revolves around a family of New York cops.
# 155    A modern update finds the famous sleuth and hi...
# 196    A chronicle of the lives of the British aristo...
# 227    When Steve McGarrett returns home to Oahu to f...
# ...                                                  ...
# 49761  Sheriff Deputy Rick Grimes wakes up from a com...
# 49811  Sheriff Deputy Rick Grimes wakes up from a com...
# 49861  Sheriff Deputy Rick Grimes wakes up from a com...
# 49911  Sheriff Deputy Rick Grimes wakes up from a com...
# 49961  Sheriff Deputy Rick Grimes wakes up from a com...
#
# [1009 rows x 7 columns]

# %%
import re

text = 'gfgfdAAA1234ZZZuijjk'

try:
    found = re.search('AAA(.+?)ZZZ', text).group(1)
except AttributeError:
    # AAA, ZZZ not found in the original string
    found = '' # apply your error handling

# found: 1234

# %%
print(found)
# Out:
# 1234

# %%
def year(text):
    try:
        found = re.search('((.+?)', text).group(1)
    except AttributeError:
        # (, - not found in the original string
        found = '' # apply your error handling
    print(found)

# %%
def year(text):
    try:
        found = re.search('((.+?)', text).group(1)
        
        #(pattern, string, flags=0)
    except AttributeError:
        # (, - not found in the original string
        found = '' # apply your error handling
    print(found)

# %%
#df['Year']=df.apply(year,axis=1)
year('(2011-2022)')
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-6-5c5c2085d6f5> in <module>
#       1 #df['Year']=df.apply(year,axis=1)
# ----> 2 year('(2011-2022)')
#
# <ipython-input-5-75c100e57cde> in year(text)
#       1 def year(text):
#       2     try:
# ----> 3         found = re.search('((.+?)', text).group(1)
#       4
#       5         #(pattern, string, flags=0)
#
# ~\anaconda3\lib\re.py in search(pattern, string, flags)
#     199     """Scan through string looking for a match to the pattern, returning
#     200     a Match object, or None if no match was found."""
# --> 201     return _compile(pattern, flags).search(string)
#     202
#     203 def sub(pattern, repl, string, count=0, flags=0):
#
# ~\anaconda3\lib\re.py in _compile(pattern, flags)
#     302     if not sre_compile.isstring(pattern):
#     303         raise TypeError("first argument must be string or compiled pattern")
# --> 304     p = sre_compile.compile(pattern, flags)
#     305     if not (flags & DEBUG):
#     306         if len(_cache) >= _MAXCACHE:
#
# ~\anaconda3\lib\sre_compile.py in compile(p, flags)
#     762     if isstring(p):
#     763         pattern = p
# --> 764         p = sre_parse.parse(p, flags)
#     765     else:
#     766         pattern = None
#
# ~\anaconda3\lib\sre_parse.py in parse(str, flags, state)
#     946
#     947     try:
# --> 948         p = _parse_sub(source, state, flags & SRE_FLAG_VERBOSE, 0)
#     949     except Verbose:
#     950         # the VERBOSE flag was switched on inside the pattern.  to be
#
# ~\anaconda3\lib\sre_parse.py in _parse_sub(source, state, verbose, nested)
#     441     start = source.tell()
#     442     while True:
# --> 443         itemsappend(_parse(source, state, verbose, nested + 1,
#     444                            not nested and not items))
#     445         if not sourcematch("|"):
#
# ~\anaconda3\lib\sre_parse.py in _parse(source, state, verbose, nested, first)
#     834             p = _parse_sub(source, state, sub_verbose, nested + 1)
#     835             if not source.match(")"):
# --> 836                 raise source.error("missing ), unterminated subpattern",
#     837                                    source.tell() - start)
#     838             if group is not None:
#
# error: missing ), unterminated subpattern at position 0
