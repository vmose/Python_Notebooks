# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv(r'C:\Input\TV Series.csv')
df.head()
# Out:
#       Series Title Release Year Runtime                    Genre Rating  \
# 0        Wednesday     (2022– )  45 min   Comedy, Crime, Fantasy    8.2
# 1      Yellowstone     (2018– )  60 min           Drama, Western    8.7
# 2  The White Lotus  (2021–2023)  60 min            Comedy, Drama    7.9
# 3             1923  (2022–2023)  60 min           Drama, Western    8.6
# 4        Jack Ryan     (2018– )  60 min  Action, Drama, Thriller    8.0
#
#                                                 Cast  \
# 0  Jenna Ortega, Hunter Doohan, Percy Hynes White...
# 1  Kevin Costner, Luke Grimes, Kelly Reilly, Wes ...
# 2  Jennifer Coolidge, Jon Gries, F. Murray Abraha...
# 3  Harrison Ford, Helen Mirren, Brandon Sklenar, ...
# 4  John Krasinski, Wendell Pierce, Michael Kelly,...
#
#                                             Synopsis
# 0  Follows Wednesday Addams' years as a student, ...
# 1  A ranching family in Montana faces off against...
# ...

# %%
df.sort_values('Rating',ascending=False)
# Out:
#              Series Title Release Year Runtime                      Genre  \
# 2790   His Dark Materials       (2003)    ****  Adventure, Drama, Fantasy
# 8134   Roadworthy Rescues     (2022– )    ****                       ****
# 9173   Dallyeola Bangtan!     (2015– )    ****                  Game-Show
# 202                 Bluey     (2018– )   7 min          Animation, Family
# 16621        Breaking Bad  (2008–2013)  49 min     Crime, Drama, Thriller
# ...                   ...          ...     ...                        ...
# 33809      The Last of Us     (2023– )    ****   Action, Adventure, Drama
# 44659      The Last of Us     (2023– )    ****   Action, Adventure, Drama
# 4053    Gangs of New York          NaN    ****                      Drama
# 6437           Unsinkable          NaN    ****                Action, War
# 35859      The Last of Us     (2023– )    ****   Action, Adventure, Drama
#
#       Rating                                               Cast  \
# ...

# %%
# for i in range(0, len(df)):
#     df['Released_On'][i] = str(df['Release Year'][i][1:5])
for i in range(0, len(df)):
    df.loc[i, 'Released_On'] = str(df.loc[i, 'Release Year'])[1:5]

# %%
df[['Release Year','Released_On']]
# Out:
#       Release Year Released_On
# 0         (2022– )        2022
# 1         (2018– )        2018
# 2      (2021–2023)        2021
# 3      (2022–2023)        2022
# 4         (2018– )        2018
# ...            ...         ...
# 49995     (1999– )        1999
# 49996     (2005– )        2005
# 49997     (2022– )        2022
# 49998     (2022– )        2022
# 49999  (2005–2020)        2005
#
# [50000 rows x 2 columns]

# %%
from sklearn.datasets import load_diabetes
diabetes=load_diabetes()

# %%
diabetes.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'DESCR', 'feature_names', 'data_filename', 'target_filename'])

# %%
import pandas as pd
x=pd.DataFrame(diabetes['data'],columns=diabetes['feature_names'])
x.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019908 -0.017646
# 1 -0.039493 -0.068330 -0.092204
# 2 -0.002592  0.002864 -0.025930
# 3  0.034309  0.022692 -0.009362
# 4 -0.002592 -0.031991 -0.046641

# %%
from sklearn.preprocessing import StandardScaler
SS=StandardScaler()

# %%
from sklearn.model_selection import train_test_split

# %%
SS.fit(x,diabetes['target'])
# Out:
# StandardScaler()

# %%
Scaled_Data=SS.transform(x)

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression()

# %%
X_train, X_test, y_train, y_test = train_test_split(x, diabetes['target'], test_size=0.33, random_state=42)

# %%
LR.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
pd.DataFrame(LR.coef_,columns=['Coefficients'],index=x.columns)
# Out:
#      Coefficients
# age     32.145673
# sex   -242.825820
# bmi    559.987382
# bp     407.641665
# s1    -718.687039
# s2     396.630109
# s3      10.423048
# s4     171.811776
# s5     627.079764
# s6     -21.624207

# %%
print("The interce#LR.intercept_)
# Out:
# The intercept is: 150.4339752023493

# %%
#Scaled_Data[1]
pred=np.array([1,1,0,1.4,0.2,-0.5,0.3,-0.2,1,-1.2])
LR.predict(pred.reshape(10,1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-150290eac1f8> in <module>
#       1 #Scaled_Data[1]
#       2 pred=np.array([1,1,0,1.4,0.2,-0.5,0.3,-0.2,1,-1.2])
# ----> 3 LR.predict(pred.reshape(10,1))
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     236             Returns predicted values.
#     237         """
# --> 238         return self._decision_function(X)
#     239
#     240     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     219
#     220         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
# --> 221         return safe_sparse_dot(X, self.coef_.T,
#     222                                dense_output=True) + self.intercept_
#     223
#
# ...

# %%
pd
# Out:
# <module 'pandas' from 'C:\\Users\\hp\\anaconda3\\lib\\site-packages\\pandas\\__init__.py'>
