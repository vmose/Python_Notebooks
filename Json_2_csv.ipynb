# %%
import json
import csv

def convert_json_to_csv(json_data):
    data = json.loads(json_data)

    # Extracting the parts from the JSON data
    parts = data["parts"]

    # Assuming all parts have the same keys, we'll use the keys from the first part as the fieldnames in the CSV
    fieldnames = [field["id"] for field in parts[0]["fields"]]

    # Open the output CSV file in write mode
    with open("output.csv", "w", newline="") as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

        # Write the header row
        writer.writeheader()

        # Write each part as a row in the CSV
        for part in parts:
            writer.writerow({field["id"]: field.get("en_US", "") for field in part["fields"]})

    print("Conversion completed. The CSV file has been created.")

# Example usage: assuming your JSON data is stored in a variable called 'json_data'
json_data = """
{"parts":[{"datastream":"wbu_sales_screening","part_id":"pt_0","input":null,"path":null,"formulae":[],"fields":[{"id":"_datetime","type":"datetime","en_US":"Date TY","path":"date_time","field":"_datetime","virtual":null,"alias":"pt0___datetime","formula":null,"expr":null,"format":"ddd D/MM/YY","global_alias":null,"aggregator":"TakeFirst","sort":null,"input":null,"pivot_aggregator":null,"pivot_dimension":null,"width":null},{"id":"row_net_total","type":"float","en_US":"Sales $ TY","path":"row_net_total","field":"row_net_total","virtual":null,"alias":"pt0__row_net_total","formula":null,"expr":null,"format":"0,0.00","global_alias":null,"aggregator":"Sum","sort":null,"input":null,"pivot_aggregator":null,"pivot_dimension":null,"width":null},{"id":"u_doc_id","type":"str","en_US":"Visits TY","path":null,"field":"u_doc_id","virtual":"concat(client_code,':',sales_document_id)","alias":"pt0__u_doc_id","formula":null,"expr":null,"format":null,"global_alias":null,"aggregator":"CountDistinct","sort":null,"input":null,"pivot_aggregator":null,"pivot_dimension":null,"width":null},{"id":"Q6BSE","type":"str","en_US":"Week TY","path":null,"field":null,"virtual":null,"alias":"pt0__week","formula":"Fn.dateformat(row['pt0___datetime'],'%V-%u')","expr":"formula","format":null,"global_alias":null,"aggregator":null,"sort":"asc","input":null,"pivot_aggregator":null,"pivot_dimension":null,"width":null},{"id":"X7OIN","type":"str","en_US":"Fullweek TY","path":null,"field":null,"virtual":null,"alias":"pt0__fw","formula":"Fn.dateformat(row['pt0___datetime'],'%G-%V-%u')","expr":"formula","format":null,"global_alias":null,"aggregator":"TakeFirst","sort":null,"input":null,"pivot_aggregator":null,"pivot_dimension":null,"width":null}],"filters":[{"id":"_datetime","type":"datetime","en_US":"Document date and time","path":"date_time","field":"_datetime","virtual":null,"alias":"pt0___datetime","formula":null,"expr":null,"format":null,"global_alias":null,"aggregator":null,"sort":null,"input":null,"pivot_aggregator":null,"pivot_dimension":null,"width":null,"mode":"detail","operator":"in date range","value":null},{"id":"warehouse_id","type":"str","en_US":"Location ID","path":"warehouse_id","field":"warehouse_id","virtual":null,"alias":"pt0__warehouse_id","formula":null,"expr":null,"format":null,"global_alias":null,"aggregator":null,"sort":null,"input":null,"pivot_aggregator":null,"pivot_dimension":null,"width":null,"mode":"detail","operator":"in context","value":"wbu_locations"},{"id":"client_code","type":"str","en_US":"Client code","path":"client_code","field":"client_code","virtual":null,"alias":"pt0__client_code","formula":null,"expr":null,"format":null,"mode":"detail","operator":"=","value":"105004"}],"joins":[],"timeshift":null,"title":"Sales history"},{"datastream":"wbu_sales_screening","part_id":"pt_1","input":null,"path":null,"formulae":[],"fields":[{"id":"_datetime","type":"datetime","en_US":"Date LY","path":"date_time","field":"_datetime","virtual":null,"alias":"pt1___datetime","formula":null,"expr":null,"format":"ddd D/MM/YY","global_alias":null,"aggregator":"TakeFirst","sort":null,"input":null,"pivot_aggregator":null,"pivot_dimension":null,"width":null},{"id":"2C7HY","type":"str","en_US":"week LY","path":null,"field":null,"virtual":null,"alias":"pt1__week","formula":"Fn.dateformat(row['pt1___datetime'],'%V-%u')","expr":"formula","format":null,"global_alias":null,"aggregator":null,"sort":null,"input":null,"pivot_aggregator":null,"pivot_dimension":null,"width":null},{"id":"row_net_total","type":"float","en_US":"Sales $ LY","path":"row_net_total","field":"row_net_total","virtual":null,"alias":"pt1__row_net_total","formula":null,"expr":null,"format":"0,0.00","global_alias":null,"aggregator":"Sum","sort":null,"input":null,"pivot_aggregator":null,"pivot_dimension":null,"width":null},{"id":"u_doc_id","type":"str","en_US":"Visits LY","path":null,"field":"u_doc_id","virtual":"concat(client_code,':',sales_document_id)","alias":"pt1__u_doc_id","formula":null,"expr":null,"format":null,"global_alias":null,"aggregator":"CountDistinct","sort":null,"input":null,"pivot_aggregator":null,"pivot_dimension":null,"width":null},{"id":"3JJGK","type":"str","en_US":"FullWeek","path":null,"field":null,"virtual":null,"alias":"pt1__fw","formula":"Fn.dateformat(row['pt1___datetime'],'%G-%V-%u')","expr":"formula","format":null,"global_alias":null,"aggregator":"TakeFirst","sort":null,"input":null,"pivot_aggregator":null,"pivot_dimension":null,"width":null}],"filters":[{"id":"_datetime","type":"datetime","en_US":"Document date and time","path":"date_time","field":"_datetime","virtual":null,"alias":"pt1___datetime","formula":null,"expr":null,"format":null,"global_alias":null,"aggregator":null,"sort":null,"input":null,"pivot_aggregator":null,"pivot_dimension":null,"width":null,"mode":"detail","operator":"in date range","value":null},{"id":"warehouse_id","type":"str","en_US":"Location ID","path":"warehouse_id","field":"warehouse_id","virtual":null,"alias":"pt1__warehouse_id","formula":null,"expr":null,"format":null,"global_alias":null,"aggregator":null,"sort":null,"input":null,"pivot_aggregator":null,"pivot_dimension":null,"width":null,"mode":"detail","operator":"in context","value":"wbu_locations"},{"id":"client_code","type":"str","en_US":"Client code","path":"client_code","field":"client_code","virtual":null,"alias":"pt1__client_code","formula":null,"expr":null,"format":null,"mode":"detail","operator":"=","value":"105004"}],"joins":[{"left":"pt0__week","right":"pt1__week","mode":"full"}],"timeshift":{"shift":-1,"unit":"years"},"title":"Sales history"}],"formula":[{"id":"LYAlign","type":"float","en_US":null,"path":null,"field":null,"virtual":null,"alias":"LYAlign","formula":null,"expr":null,"format":null,"global_alias":null,"aggregator":"('-').join([str(int(row['pt1__fw'][0].split('-')[0])+1),row['pt1__fw'][0].split('-')[1],row['pt1__fw'][0].split('-')[2]])","sort":null,"input":null,"pivot_aggregator":null,"pivot_dimension":null,"width":null},{"id":"MaxWeek","type":"float","en_US":null,"path":null,"field":null,"virtual":null,"alias":"MaxWeek","formula":null,"expr":null,"format":null,"global_alias":null,"aggregator":"Fn.max(row['pt0__fw'][0] if row['pt0__fw'] else '0',row['LYAlign'])","sort":null,"input":null,"pivot_aggregator":null,"pivot_dimension":null,"width":null},{"id":"SortWeek","type":"float","en_US":null,"path":null,"field":null,"virtual":null,"alias":"SortWeek","formula":null,"expr":null,"format":"0,0.00","global_alias":null,"aggregator":"Fn.Sort('MaxWeek')","sort":null,"input":null,"pivot_aggregator":null,"pivot_dimension":null,"width":null},{"id":"$ Diff (sales)","type":"float","en_US":null,"path":null,"field":null,"virtual":null,"alias":"$ Diff (sales)","formula":null,"expr":null,"format":"0%","global_alias":null,"aggregator":"row['pt0__row_net_total']-row['pt1__row_net_total']","sort":null,"input":null,"pivot_aggregator":null,"pivot_dimension":null,"width":null},{"id":"% Diff (sales)","type":"float","en_US":null,"path":null,"field":null,"virtual":null,"alias":"% Diff (sales)","formula":null,"expr":null,"format":"0%","global_alias":null,"aggregator":"row['pt0__row_net_total']/row['pt1__row_net_total']","sort":null,"input":null,"pivot_aggregator":null,"pivot_dimension":null,"width":null},{"id":"% Diff (visits)","type":"float","en_US":null,"path":null,"field":null,"virtual":null,"alias":"% Diff (visits)","formula":null,"expr":null,"format":"0,0.00","global_alias":null,"aggregator":"row['pt0__u_doc_id']/row['pt1__u_doc_id']","sort":null,"input":null,"pivot_aggregator":null,"pivot_dimension":null,"width":null},{"id":"$ Avg tkt TY","type":"float","en_US":null,"path":null,"field":null,"virtual":null,"alias":"$ Avg tkt TY","formula":null,"expr":null,"format":"0,0.00","global_alias":null,"aggregator":"row['pt0__row_net_total']/row['pt0__u_doc_id']","sort":null,"input":null,"pivot_aggregator":null,"pivot_dimension":null,"width":null},{"id":"$ Avg tkt LY","type":"float","en_US":null,"path":null,"field":null,"virtual":null,"alias":"$ Avg tkt LY","formula":null,"expr":null,"format":"0%","global_alias":null,"aggregator":"row['pt1__row_net_total']/row['pt1__u_doc_id']","sort":null,"input":null,"pivot_aggregator":null,"pivot_dimension":null,"width":null},{"id":"% Diff (avg tkt)","type":"float","en_US":null,"path":null,"field":null,"virtual":null,"alias":"% Diff (avg tkt)","formula":null,"expr":null,"format":null,"global_alias":null,"aggregator":"row['$ Avg tkt TY']/row['$ Avg tkt LY']","sort":null,"input":null,"pivot_aggregator":null,"pivot_dimension":null,"width":null}],"layout":[{"id":"_datetime","type":"datetime","en_US":"Date TY","path":"date_time","field":"_datetime","virtual":null,"alias":"pt0___datetime","formula":null,"expr":null,"format":"ddd M/DD/YY","global_alias":null,"aggregator":"TakeFirst","sort":null,"input":null,"pivot_aggregator":null,"pivot_dimension":null,"width":null},{"id":"_datetime","type":"datetime","en_US":"Date LY","path":"date_time","field":"_datetime","virtual":null,"alias":"pt1___datetime","formula":null,"expr":null,"format":"ddd M/DD/YY","global_alias":null,"aggregator":"TakeFirst","sort":null,"input":null,"pivot_aggregator":null,"pivot_dimension":null,"width":null},{"id":"row_net_total","type":"float","en_US":"Sales $ TY","path":"row_net_total","field":"row_net_total","virtual":null,"alias":"pt0__row_net_total","formula":null,"expr":null,"format":"0,0.00","global_alias":null,"aggregator":"Sum","sort":null,"input":null,"pivot_aggregator":null,"pivot_dimension":null,"width":null},{"id":"row_net_total","type":"float","en_US":"Sales $ LY","path":"row_net_total","field":"row_net_total","virtual":null,"alias":"pt1__row_net_total","formula":null,"expr":null,"format":"0,0.00","global_alias":null,"aggregator":"Sum","sort":null,"input":null,"pivot_aggregator":null,"pivot_dimension":null,"width":null},{"id":"$ Diff (sales)","type":"float","en_US":null,"path":null,"field":null,"virtual":null,"alias":"$ Diff (sales)","formula":null,"expr":null,"format":"0,0.00","global_alias":null,"aggregator":"row['pt0__row_net_total']-row['pt1__row_net_total']","sort":null,"input":null,"pivot_aggregator":null,"pivot_dimension":null,"width":null},{"id":"% Diff (sales)","type":"float","en_US":null,"path":null,"field":null,"virtual":null,"alias":"% Diff (sales)","formula":null,"expr":null,"format":"0%","global_alias":null,"aggregator":"row['pt0__row_net_total']/row['pt1__row_net_total']","sort":null,"input":null,"pivot_aggregator":null,"pivot_dimension":null,"width":null},{"id":"u_doc_id","type":"str","en_US":"Visits TY","path":null,"field":"u_doc_id","virtual":"concat(client_code,':',sales_document_id)","alias":"pt0__u_doc_id","formula":null,"expr":null,"format":"0,0","global_alias":null,"aggregator":"CountDistinct","sort":null,"input":null,"pivot_aggregator":null,"pivot_dimension":null,"width":null},{"id":"u_doc_id","type":"str","en_US":"Visits LY","path":null,"field":"u_doc_id","virtual":"concat(client_code,':',sales_document_id)","alias":"pt1__u_doc_id","formula":null,"expr":null,"format":"0,0","global_alias":null,"aggregator":"CountDistinct","sort":null,"input":null,"pivot_aggregator":null,"pivot_dimension":null,"width":null},{"id":"% Diff (visits)","type":"float","en_US":null,"path":null,"field":null,"virtual":null,"alias":"% Diff (visits)","formula":null,"expr":null,"format":"0%","global_alias":null,"aggregator":"row['pt0__u_doc_id']/row['pt1__u_doc_id']","sort":null,"input":null,"pivot_aggregator":null,"pivot_dimension":null,"width":null},{"id":"$ Avg tkt TY","type":"float","en_US":null,"path":null,"field":null,"virtual":null,"alias":"$ Avg tkt TY","formula":null,"expr":null,"format":"0,0.00","global_alias":null,"aggregator":"row['pt0__row_net_total']/row['pt0__u_doc_id']","sort":null,"input":null,"pivot_aggregator":null,"pivot_dimension":null,"width":null},{"id":"$ Avg tkt LY","type":"float","en_US":null,"path":null,"field":null,"virtual":null,"alias":"$ Avg tkt LY","formula":null,"expr":null,"format":"0,0.00","global_alias":null,"aggregator":"row['pt1__row_net_total']/row['pt1__u_doc_id']","sort":null,"input":null,"pivot_aggregator":null,"pivot_dimension":null,"width":null},{"id":"% Diff (avg tkt)","type":"float","en_US":null,"path":null,"field":null,"virtual":null,"alias":"% Diff (avg tkt)","formula":null,"expr":null,"format":"0%","global_alias":null,"aggregator":"row['$ Avg tkt TY']/row['$ Avg tkt LY']","sort":null,"input":null,"pivot_aggregator":null,"pivot_dimension":null,"width":null}],"fields":[],"filters":[],"visualisation":{"type":"piechart"},"limit":null,"context":[{"key":null,"label":"WBU Locations","d":"wbu_locations","e":"all","p":[]}],"actions":[{"api":"stream_upload","parameters":["tjx_planner_com_bal_file"],"label":"Upload commitment balance adjustments","data":false}],"pivot":null,"ui":{}}
"""

convert_json_to_csv(json_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-4d4d7abbc6d2> in <module>
#      29 """
#      30
# ---> 31 convert_json_to_csv(json_data)
#
# <ipython-input-1-4d4d7abbc6d2> in convert_json_to_csv(json_data)
#      20         # Write each part as a row in the CSV
#      21         for part in parts:
# ---> 22             writer.writerow({field["id"]: field.get("en_US", "") for field in part["fields"]})
#      23
#      24     print("Conversion completed. The CSV file has been created.")
#
# ~\anaconda3\lib\csv.py in writerow(self, rowdict)
#     152
#     153     def writerow(self, rowdict):
# --> 154         return self.writer.writerow(self._dict_to_list(rowdict))
#     155
#     156     def writerows(self, rowdicts):
#
# ~\anaconda3\lib\csv.py in _dict_to_list(self, rowdict)
#     147             wrong_fields = rowdict.keys() - self.fieldnames
# ...
